# %%
# Download these files

# books_titles.json
# https://drive.google.com/file/d/1Iqv9TROqNgYbUDijSaDegv4EPpxO97t3/view?usp=sharing

# goodreads_interactions.csv
# https://drive.google.com/open?id=1zmylV7XW2dfQVCLeg1LbllfQtHD2KUon

# book_id_map.csv
# https://drive.google.com/uc?id=1CHTAaNwyzvbi1TR08MJrJ03BxA266Yxr

# liked_books.csv
# https://drive.google.com/file/d/1dhPhfD5hAOJjrdf8JhvbOPxDpF4qWYnb/view?usp=sharing

# Full code is at https://github.com/dataquestio/project-walkthroughs/tree/master/books

import pandas as pd

my_books = pd.read_csv("liked_books_full.csv", index_col=0)
my_books["book_id"] = my_books["book_id"].astype(str)

# %%
# %cd /content/drive/MyDrive/bookRecommendation
# Out:
# /content/drive/MyDrive/bookRecommendation

# %%
ls
# Out:
# book_id_map.csv  books_titles.json  goodreads_interactions.csv  liked_books.csv

# %%
import pandas as pd
my_books = pd.read_csv("liked_books.csv", index_col=0)
my_books["book_id"] = my_books["book_id"].astype(str)

# %%
my_books
# Out:
#      user_id   book_id  rating  \
# 0         -1   2517439       5
# 1         -1    113576       5
# 2         -1     35100       5
# 3         -1    228221       5
# 5         -1  17662739       5
# 6         -1    356824       5
# 7         -1  12125412       5
# 8         -1    139069       5
# 10        -1     76680       5
# 11        -1      1898       5
# 12        -1   5096865       5
# 13        -1    228665       5
# 17        -1    437143       5
# 18        -1  18949861       5
# 19        -1   2913377       5
# 20        -1   1215032       5
# 21        -1    883438       5
# 22        -1   5578108       5
# 23        -1    128029       5
# 24        -1     77203       5
# 25        -1      5439       5
# 26        -1   1685995       5
# 27        -1   6448772       5
# 527       -1   8161140       1
# 528       -1     28187       1
# 531       -1  25659450       1
# 532       -1     82599       1
#
#                                                  title
# 0               The Forever War  (The Forever War, #1)
# 1    The Smartest Guys in the Room: The Amazing Ris...
# 2                                Battle Cry of Freedom
# 3                                  The Mask of Command
# 5           2001: A Space Odyssey  (Space Odyssey, #1)
# 6    India After Gandhi: The History of the World's...
# 7      The Lady or the Tiger?: and Other Logic Puzzles
# 8            Endurance: Shackleton's Incredible Voyage
# 10                        Foundation  (Foundation, #1)
# 11   Into Thin Air: A Personal Account of the Mount...
# 12                                       In Cold Blood
# 13       The Eye of the World  (The Wheel of Time, #1)
# 17                A Short History of Nearly Everything
# 18                                             Contact
# 19   The Name of the Wind  (The Kingkiller Chronicl...
# 20   The Wise Man's Fear  (The Kingkiller Chronicle...
# 21                                        East of Eden
# 22   From Colony to Superpower: U.S. Foreign Relati...
# 23                            A Thousand Splendid Suns
# 24                                     The Kite Runner
# 25                             Interpreter of Maladies
# 26                                     Dune  (Dune #1)
# 27   Quantum: Einstein, Bohr, and the Great Debate ...
# 527                                       On the Beach
# 528  The Lightning Thief  (Percy Jackson and the Ol...
# 531                                          Arkwright
# 532                                   Rabbits: A Novel

# %% [markdown]
# Mapping id of the interaction file and title file

# %%
#Reads line by line so that we don't have to strore everything in a pandas dataframe
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
# Look for users who has read the same books as us. set gives us unique values
book_set = set(my_books["book_id"])

# %%
# Lets check what is in interactions file
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %%
#check no. of lines in interactions file
# !wc -l goodreads_interactions.csv
# Out:
# 228648343 goodreads_interactions.csv

# %%
# Find the no. of overlap readers
overlap_users = {}

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        # if this is one of the books we have read, then add it to the list of overlap user
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 316341

# %%
# The number of books the users have read that overlap with us is atleast 20%(random number)
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/5])

# %%
# For every user that has read same books as us, look through the books they have read. 
#This will help in building recommendation
interactions_list = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %%
len(interactions_list)
# Out:
# 5638701

# %%
interactions_list[0]
# Out:
# ['282', '627206', '4']

# %% [markdown]
# Collaborative filtering(Generate matrix- user item)

# %%
# convert to dataframe
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])

# %%
# concatenate mybooks(list of liked books) and interactions
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 5            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    475178      0
# 5638697  804100    186074      0
# 5638698  804100    153008      0
# 5638699  804100     45107      0
# 5638700  804100   1762198      5
#
# [5638755 rows x 3 columns]

# %%
# convert user_id and book_id to string and rating to number
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
interactions['user_id'].unique()
# Out:
# array(['-1', '282', '874', ..., '442043', '712588', '804100'],
#       dtype=object)

# %%
len(interactions['user_id'].unique())
# Out:
# 1259

# %%
# create a column called user index which categorizes each unique id into a category
# and gives a codes starting from 0(Basically map a userid to a position)
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
interactions.iloc[0]
# Out:
# user_id            -1
# book_id       2517439
# rating              5
# user_index          0
# book_index     414880
# Name: 0, dtype: object

# %%
interactions['user_index'].unique()
# Out:
# array([   0,  555, 1216, ..., 1054, 1143, 1183], dtype=int16)

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
len(interactions['book_index'].unique())
# Out:
# 802870

# %%
#no. of unique matrix cells
1259 * 802870
# Out:
# 1010813330

# %%
# create sparse matrix to save memory using scipy
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <1259x802870 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5638755 stored elements in COOrdinate format>

# %%
# convert matrix from coo format to csr
ratings_mat = ratings_mat_coo.tocsr()

# %% [markdown]
# Find users similar to us

# %%
# find row position of our specific user and userid was -1 in predferences file
interactions[interactions["user_id"] == "-1"]
# Out:
#     user_id   book_id  rating  user_index  book_index
# 0        -1   2517439       5           0      414880
# 1        -1    113576       5           0       38971
# 2        -1     35100       5           0      575858
# 3        -1    228221       5           0      356004
# 5        -1  17662739       5           0      214285
# 6        -1    356824       5           0      581743
# 7        -1  12125412       5           0       59763
# 8        -1    139069       5           0      124430
# 10       -1     76680       5           0      722098
# 11       -1      1898       5           0      276178
# 12       -1   5096865       5           0      625929
# 13       -1    228665       5           0      357774
# 17       -1    437143       5           0      607659
# 18       -1  18949861       5           0      275433
# 19       -1   2913377       5           0      496223
# 20       -1   1215032       5           0       60398
# 21       -1    883438       5           0      767233
# 22       -1   5578108       5           0      637486
# 23       -1    128029       5           0       78172
# 24       -1     77203       5           0      724379
# 25       -1      5439       5           0      633999
# 26       -1   1685995       5           0      188133
# 27       -1   6448772       5           0      671711
# 527      -1   8161140       1           0      742532
# 528      -1     28187       1           0      480322
# 531      -1  25659450       1           0      431105
# 532      -1     82599       1           0      746448
# 0        -1   2517439       5           0      414880
# 1        -1    113576       5           0       38971
# 2        -1     35100       5           0      575858
# 3        -1    228221       5           0      356004
# 5        -1  17662739       5           0      214285
# 6        -1    356824       5           0      581743
# 7        -1  12125412       5           0       59763
# 8        -1    139069       5           0      124430
# 10       -1     76680       5           0      722098
# 11       -1      1898       5           0      276178
# 12       -1   5096865       5           0      625929
# 13       -1    228665       5           0      357774
# 17       -1    437143       5           0      607659
# 18       -1  18949861       5           0      275433
# 19       -1   2913377       5           0      496223
# 20       -1   1215032       5           0       60398
# 21       -1    883438       5           0      767233
# 22       -1   5578108       5           0      637486
# 23       -1    128029       5           0       78172
# 24       -1     77203       5           0      724379
# 25       -1      5439       5           0      633999
# 26       -1   1685995       5           0      188133
# 27       -1   6448772       5           0      671711
# 527      -1   8161140       1           0      742532
# 528      -1     28187       1           0      480322
# 531      -1  25659450       1           0      431105
# 532      -1     82599       1           0      746448

# %%
# this matches to user_index 0
my_index = 0

# %%
# find users who are similar to us(similar taste as us). Use cosine similarity 
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
#how similar are we to us
similarity[0]
# Out:
# 0.9999999999999999

# %%
similarity[2]
# Out:
# 0.06143442518998915

# %%
# 15 users who are most similar to us(find positions)
import numpy as np

indices = np.argpartition(similarity, -15)[-15:]

# %%
indices
# Out:
# array([1188,  942,  218,  129,  496,  435, 1208,  795, 1213, 1210, 1143,
#         321,  294,  862,    0])

# %%
# find users in interactions which are in the indices
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
# remove our user so that we don't get our own recommendation
similar_users = similar_users[similar_users["user_id"]!="-1"]

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 45312      4133      5359       3         942      632143
# 45313      4133  10464963       4         942       13492
# 45314      4133      3858       3         942      593622
# 45315      4133  11827808       4         942       51904
# 45316      4133   7913305       4         942      732465
# ...         ...       ...     ...         ...         ...
# 5638521  712588  32388712       3        1143      543119
# 5638522  712588     16322       5        1143      183365
# 5638523  712588    860543       0        1143      759827
# 5638524  712588    853510       5        1143      756768
# 5638525  712588     13890       4        1143      124251
#
# [4302 rows x 5 columns]

# %% [markdown]
# Create book recommendations

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 1             6  3.833333
# 100322        1  0.000000
# 100365        1  0.000000
# 10046142      1  0.000000
# 1005          3  0.000000
# ...         ...       ...
# 99561         2  2.500000
# 99610         1  3.000000
# 99664         1  4.000000
# 9969571       3  2.333333
# 99944         1  0.000000
#
# [2856 rows x 2 columns]

# %%
# Now to identify book titles from book_id we need the titles file
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
# merge with titles on book_id
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#        book_id  count      mean  \
# 0            1      6  3.833333
# 1       100322      1  0.000000
# 2       100365      1  0.000000
# 3     10046142      1  0.000000
# 4         1005      3  0.000000
# ...        ...    ...       ...
# 2849     99561      2  2.500000
# 2850     99610      1  3.000000
# 2851     99664      1  4.000000
# 2852   9969571      3  2.333333
# 2853     99944      1  0.000000
#
#                                                   title  ratings  \
# 0     Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                              Assata: An Autobiography    11057
# 2                                 The Mote in God's Eye    48736
# 3     Dancing in the Glory of Monsters: The Collapse...     2391
# 4                                   Think and Grow Rich    87634
# ...                                                 ...      ...
# 2849                                 Looking for Alaska   804587
# 2850                                The Best Laid Plans    17434
# 2851                                   The Painted Veil    24606
# 2852                                   Ready Player One   376328
# 2853                                  The Bhagavad Gita    33855
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/1.Harry_Po...
# 1     https://www.goodreads.com/book/show/100322.Assata
# 2     https://www.goodreads.com/book/show/100365.The...
# 3     https://www.goodreads.com/book/show/10046142-d...
# 4     https://www.goodreads.com/book/show/1005.Think...
# ...                                                 ...
# 2849  https://www.goodreads.com/book/show/99561.Look...
# 2850  https://www.goodreads.com/book/show/99610.The_...
# 2851  https://www.goodreads.com/book/show/99664.The_...
# 2852  https://www.goodreads.com/book/show/9969571-re...
# 2853  https://www.goodreads.com/book/show/99944.The_...
#
#                                             cover_image  \
# 0     https://images.gr-assets.com/books/1361039191m...
# 1     https://images.gr-assets.com/books/1328857268m...
# 2     https://images.gr-assets.com/books/1399490037m...
# 3     https://images.gr-assets.com/books/1328757755m...
# 4     https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                 ...
# 2849  https://images.gr-assets.com/books/1394798630m...
# 2850  https://images.gr-assets.com/books/1353374848m...
# 2851  https://images.gr-assets.com/books/1320421719m...
# 2852  https://images.gr-assets.com/books/1500930947m...
# 2853  https://images.gr-assets.com/books/1383059639m...
#
#                                               mod_title
# 0     harry potter and the halfblood prince harry po...
# 1                               assata an autobiography
# 2                                  the mote in gods eye
# 3     dancing in the glory of monsters the collapse ...
# 4                                   think and grow rich
# ...                                                 ...
# 2849                                 looking for alaska
# 2850                                the best laid plans
# 2851                                   the painted veil
# 2852                                   ready player one
# 2853                                  the bhagavad gita
#
# [2854 rows x 8 columns]

# %%
# books that are really popular among users like us(specifically tailored to our taste)
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])

# %%
#ho wmuch we might like the book
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

# %%
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()

# %%
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True)

# %%
# remove books that we have already read
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
book_recs = book_recs[book_recs["mean"] >=4]

# %%
book_recs = book_recs[book_recs["count"]>2]

# %%
top_recs = book_recs.sort_values("mean", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb694_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >mean</th>
#       <th class="col_heading level0 col3" >title</th>
#       <th class="col_heading level0 col4" >ratings</th>
#       <th class="col_heading level0 col5" >url</th>
#       <th class="col_heading level0 col6" >cover_image</th>
#       <th class="col_heading level0 col7" >mod_title</th>
#       <th class="col_heading level0 col8" >adjusted_count</th>
#       <th class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb694_level0_row0" class="row_heading level0 row0" >2265</th>
#       <td id="T_cb694_row0_col0" class="data row0 col0" >62291</td>
#       <td id="T_cb694_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_cb694_row0_col2" class="data row0 col2" >4.800000</td>
#       <td id="T_cb694_row0_col3" class="data row0 col3" >A Storm of Swords (A Song of Ice and Fire, #3)</td>
#       <td id="T_cb694_row0_col4" class="data row0 col4" >477834</td>
#       <td id="T_cb694_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/62291.A_Storm_of_Swords">Goodreads</a></td>
#       <td id="T_cb694_row0_col6" class="data row0 col6" ><a href="https://images.gr-assets.com/books/1497931121m/62291.jpg"><img src="https://images.gr-assets.com/books/1497931121m/62291.jpg" width=50></img></a></td>
#       <td id="T_cb694_row0_col7" class="data row0 col7" >a storm of swords a song of ice and fire 3</td>
#       <td id="T_cb694_row0_col8" class="data row0 col8" >0.000052</td>
#       <td id="T_cb694_row0_col9" class="data row0 col9" >0.000251</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row1" class="row_heading level0 row1" >600</th>
#       <td id="T_cb694_row1_col0" class="data row1 col0" >157993</td>
#       <td id="T_cb694_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_cb694_row1_col2" class="data row1 col2" >4.333333</td>
#       <td id="T_cb694_row1_col3" class="data row1 col3" >The Little Prince</td>
#       <td id="T_cb694_row1_col4" class="data row1 col4" >763309</td>
#       <td id="T_cb694_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/157993.The_Little_Prince">Goodreads</a></td>
#       <td id="T_cb694_row1_col6" class="data row1 col6" ><a href="https://images.gr-assets.com/books/1367545443m/157993.jpg"><img src="https://images.gr-assets.com/books/1367545443m/157993.jpg" width=50></img></a></td>
#       <td id="T_cb694_row1_col7" class="data row1 col7" >the little prince</td>
#       <td id="T_cb694_row1_col8" class="data row1 col8" >0.000012</td>
#       <td id="T_cb694_row1_col9" class="data row1 col9" >0.000051</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row2" class="row_heading level0 row2" >1103</th>
#       <td id="T_cb694_row2_col0" class="data row2 col0" >22034</td>
#       <td id="T_cb694_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_cb694_row2_col2" class="data row2 col2" >4.333333</td>
#       <td id="T_cb694_row2_col3" class="data row2 col3" >The Godfather</td>
#       <td id="T_cb694_row2_col4" class="data row2 col4" >259150</td>
#       <td id="T_cb694_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/22034.The_Godfather">Goodreads</a></td>
#       <td id="T_cb694_row2_col6" class="data row2 col6" ><a href="https://images.gr-assets.com/books/1394988109m/22034.jpg"><img src="https://images.gr-assets.com/books/1394988109m/22034.jpg" width=50></img></a></td>
#       <td id="T_cb694_row2_col7" class="data row2 col7" >the godfather</td>
#       <td id="T_cb694_row2_col8" class="data row2 col8" >0.000035</td>
#       <td id="T_cb694_row2_col9" class="data row2 col9" >0.000150</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row3" class="row_heading level0 row3" >1176</th>
#       <td id="T_cb694_row3_col0" class="data row3 col0" >2318271</td>
#       <td id="T_cb694_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_cb694_row3_col2" class="data row3 col2" >4.333333</td>
#       <td id="T_cb694_row3_col3" class="data row3 col3" >The Last Lecture</td>
#       <td id="T_cb694_row3_col4" class="data row3 col4" >245804</td>
#       <td id="T_cb694_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2318271.The_Last_Lecture">Goodreads</a></td>
#       <td id="T_cb694_row3_col6" class="data row3 col6" ><a href="https://images.gr-assets.com/books/1388075896m/2318271.jpg"><img src="https://images.gr-assets.com/books/1388075896m/2318271.jpg" width=50></img></a></td>
#       <td id="T_cb694_row3_col7" class="data row3 col7" >the last lecture</td>
#       <td id="T_cb694_row3_col8" class="data row3 col8" >0.000037</td>
#       <td id="T_cb694_row3_col9" class="data row3 col9" >0.000159</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row4" class="row_heading level0 row4" >1909</th>
#       <td id="T_cb694_row4_col0" class="data row4 col0" >4381</td>
#       <td id="T_cb694_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_cb694_row4_col2" class="data row4 col2" >4.333333</td>
#       <td id="T_cb694_row4_col3" class="data row4 col3" >Fahrenheit 451</td>
#       <td id="T_cb694_row4_col4" class="data row4 col4" >591506</td>
#       <td id="T_cb694_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/4381.Fahrenheit_451">Goodreads</a></td>
#       <td id="T_cb694_row4_col6" class="data row4 col6" ><a href="https://images.gr-assets.com/books/1351643740m/4381.jpg"><img src="https://images.gr-assets.com/books/1351643740m/4381.jpg" width=50></img></a></td>
#       <td id="T_cb694_row4_col7" class="data row4 col7" >fahrenheit 451</td>
#       <td id="T_cb694_row4_col8" class="data row4 col8" >0.000015</td>
#       <td id="T_cb694_row4_col9" class="data row4 col9" >0.000066</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row5" class="row_heading level0 row5" >243</th>
#       <td id="T_cb694_row5_col0" class="data row5 col0" >119322</td>
#       <td id="T_cb694_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_cb694_row5_col2" class="data row5 col2" >4.250000</td>
#       <td id="T_cb694_row5_col3" class="data row5 col3" >The Golden Compass (His Dark Materials, #1)</td>
#       <td id="T_cb694_row5_col4" class="data row5 col4" >973154</td>
#       <td id="T_cb694_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/119322.The_Golden_Compass">Goodreads</a></td>
#       <td id="T_cb694_row5_col6" class="data row5 col6" ><a href="https://images.gr-assets.com/books/1505766203m/119322.jpg"><img src="https://images.gr-assets.com/books/1505766203m/119322.jpg" width=50></img></a></td>
#       <td id="T_cb694_row5_col7" class="data row5 col7" >the golden compass his dark materials 1</td>
#       <td id="T_cb694_row5_col8" class="data row5 col8" >0.000016</td>
#       <td id="T_cb694_row5_col9" class="data row5 col9" >0.000070</td>
#     </tr>
#     <tr>
#       <th id="T_cb694_level0_row6" class="row_heading level0 row6" >1444</th>
#       <td id="T_cb694_row6_col0" class="data row6 col0" >2767793</td>
#       <td id="T_cb694_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_cb694_row6_col2" class="data row6 col2" >4.250000</td>
#       <td id="T_cb694_row6_col3" class="data row6 col3" >The Hero of Ages (Mistborn, #3)</td>
#       <td id="T_cb694_row6_col4" class="data row6 col4" >149260</td>
#       <td id="T_cb694_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2767793-the-hero-of-ages">Goodreads</a></td>
#       <td id="T_cb694_row6_col6" class="data row6 col6" ><a href="https://images.gr-assets.com/books/1480717763m/2767793.jpg"><img src="https://images.gr-assets.com/books/1480717763m/2767793.jpg" width=50></img></a></td>
#       <td id="T_cb694_row6_col7" class="data
