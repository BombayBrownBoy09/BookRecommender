# %%
cd /content/drive/MyDrive/bookRecommendation
# Out:
# /content/drive/MyDrive/bookRecommendation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Count the number of lines using wc**

# %%
# !wc -l goodreads_books.json.gz
# Out:
# 7588375 goodreads_books.json.gz

# %%
# !ls -lh | grep goodreads_books.json.gz
# Out:
# -r-------- 1 root root 2.0G May 16  2019 goodreads_books.json.gz

# %%
# Read line by line since the file is very large
import gzip

with gzip.open("goodreads_books.json.gz") as f:
    line = f.readline()

# %%
line
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %%
# load json using python
import json

data = json.loads(line)
data
# Out:
# {'asin': '',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'average_rating': '4.00',
#  'book_id': '5333265',
#  'country_code': 'US',
#  'description': '',
#  'edition_information': '',
#  'format': 'Paperback',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'is_ebook': 'false',
#  'isbn': '0312853122',
#  'isbn13': '9780312853129',
#  'kindle_asin': '',
#  'language_code': '',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'num_pages': '256',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'publication_day': '1',
#  'publication_month': '9',
#  'publication_year': '1984',
#  'publisher': "St. Martin's Press",
#  'ratings_count': '3',
#  'series': [],
#  'similar_books': [],
#  'text_reviews_count': '1',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'work_id': '5400751'}

# %% [markdown]
# **Parse book metadata**

# %%
# Extract only the fileds which are rewuired from the json
def parse_fields(line):
    data = json.loads(line)
    return {
        "book_id": data["book_id"], 
        "title": data["title_without_series"], 
        "ratings": data["ratings_count"], 
        "url": data["url"], 
        "cover_image": data["image_url"]
    }

# %%
# go line by line and parse each line
books_titles = []
with gzip.open("goodreads_books.json.gz") as f:
    while True:
        line = f.readline()
        if not line:
            break
        fields = parse_fields(line)
        try:
            ratings = int(fields["ratings"])
        except ValueError:
            continue
        # Only take books with more than 15 ratings to reduce the corpus
        if ratings > 15:
            books_titles.append(fields)

# %% [markdown]
# **Process the metadata**

# %%
import pandas as pd

titles = pd.DataFrame.from_dict(books_titles)
titles["ratings"] = pd.to_numeric(titles["ratings"])
titles["mod_title"] = titles["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True)
titles["mod_title"] = titles["mod_title"].str.lower()
titles["mod_title"] = titles["mod_title"].str.replace("\s+", " ", regex=True)
titles = titles[titles["mod_title"].str.len() > 0]
titles.to_json("books_titles.json")

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1302659 rows x 6 columns]

# %% [markdown]
# **Build Search engine by using TF-IDF matrix and cosine similarity**

# %%
# Search engine queries modified titles
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(titles["mod_title"])

# %%
# turn search query into vector and match it with the matrix
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

def search(query,vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]", "", query.lower())
    query_vec = vectorizer.transform([query])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    # find indices of 10 largest similarity values
    indices = np.argpartition(similarity, -10)[-10:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    
    return results.head(5).style.format({'url': make_clickable, 'cover_image': show_image})

# %%
search("business", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e947b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >title</th>
#       <th class="col_heading level0 col2" >ratings</th>
#       <th class="col_heading level0 col3" >url</th>
#       <th class="col_heading level0 col4" >cover_image</th>
#       <th class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e947b_level0_row0" class="row_heading level0 row0" >888736</th>
#       <td id="T_e947b_row0_col0" class="data row0 col0" >290583</td>
#       <td id="T_e947b_row0_col1" class="data row0 col1" >The Business</td>
#       <td id="T_e947b_row0_col2" class="data row0 col2" >4622</td>
#       <td id="T_e947b_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/290583.The_Business">Goodreads</a></td>
#       <td id="T_e947b_row0_col4" class="data row0 col4" ><a href="https://images.gr-assets.com/books/1367267580m/290583.jpg"><img src="https://images.gr-assets.com/books/1367267580m/290583.jpg" width=50></img></a></td>
#       <td id="T_e947b_row0_col5" class="data row0 col5" >the business</td>
#     </tr>
#     <tr>
#       <th id="T_e947b_level0_row1" class="row_heading level0 row1" >7261</th>
#       <td id="T_e947b_row1_col0" class="data row1 col0" >2355019</td>
#       <td id="T_e947b_row1_col1" class="data row1 col1" >The Business</td>
#       <td id="T_e947b_row1_col2" class="data row1 col2" >1326</td>
#       <td id="T_e947b_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/2355019.The_Business">Goodreads</a></td>
#       <td id="T_e947b_row1_col4" class="data row1 col4" ><a href="https://images.gr-assets.com/books/1408310200m/2355019.jpg"><img src="https://images.gr-assets.com/books/1408310200m/2355019.jpg" width=50></img></a></td>
#       <td id="T_e947b_row1_col5" class="data row1 col5" >the business</td>
#     </tr>
#     <tr>
#       <th id="T_e947b_level0_row2" class="row_heading level0 row2" >330002</th>
#       <td id="T_e947b_row2_col0" class="data row2 col0" >886124</td>
#       <td id="T_e947b_row2_col1" class="data row2 col1" >The Business</td>
#       <td id="T_e947b_row2_col2" class="data row2 col2" >295</td>
#       <td id="T_e947b_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/886124.The_Business">Goodreads</a></td>
#       <td id="T_e947b_row2_col4" class="data row2 col4" ><a href="https://images.gr-assets.com/books/1328666356m/886124.jpg"><img src="https://images.gr-assets.com/books/1328666356m/886124.jpg" width=50></img></a></td>
#       <td id="T_e947b_row2_col5" class="data row2 col5" >the business</td>
#     </tr>
#     <tr>
#       <th id="T_e947b_level0_row3" class="row_heading level0 row3" >1265227</th>
#       <td id="T_e947b_row3_col0" class="data row3 col0" >19397193</td>
#       <td id="T_e947b_row3_col1" class="data row3 col1" >Down to Business (Business, #1)</td>
#       <td id="T_e947b_row3_col2" class="data row3 col2" >211</td>
#       <td id="T_e947b_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/19397193-down-to-business">Goodreads</a></td>
#       <td id="T_e947b_row3_col4" class="data row3 col4" ><a href="https://images.gr-assets.com/books/1386867143m/19397193.jpg"><img src="https://images.gr-assets.com/books/1386867143m/19397193.jpg" width=50></img></a></td>
#       <td id="T_e947b_row3_col5" class="data row3 col5" >down to business business 1</td>
#     </tr>
#     <tr>
#       <th id="T_e947b_level0_row4" class="row_heading level0 row4" >860562</th>
#       <td id="T_e947b_row4_col0" class="data row4 col0" >567680</td>
#       <td id="T_e947b_row4_col1" class="data row4 col1" >The Business</td>
#       <td id="T_e947b_row4_col2" class="data row4 col2" >79</td>
#       <td id="T_e947b_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/567680.The_Business">Goodreads</a></td>
#       <td id="T_e947b_row4_col4" class="data row4 col4" ><a href="https://images.gr-assets.com/books/1434945304m/567680.jpg"><img src="https://images.gr-assets.com/books/1434945304m/567680.jpg" width=50></img></a></td>
#       <td id="T_e947b_row4_col5" class="data row4 col5" >the business</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Create list of liked books**

# %%
liked_books = ['22543496', '39661', '12816830', '482060', "9401317", "9317691", "8153988"]

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
# form a dictionary of books where key is csv id from interactions and value is book id from json
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
len(csv_book_mapping)
# Out:
# 2360651

# %%
csv_book_mapping['0']
# Out:
# '34684622'

# %%
# count no. of lines interaction data
# !wc -l goodreads_interactions.csv
# Out:
# 228648343 goodreads_interactions.csv

# %%
# !ls -lh | grep goodreads_interactions.csv

# %% [markdown]
# **Find users who like same books as us**

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %%
overlap_users = set()

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            continue

        try:
            rating = int(rating)
        except ValueError:
            continue
        
        #convert csvid to book id
        book_id = csv_book_mapping[csv_id]
        
        # if the booke id is in our liked books, add the user to the list of overlapped users
        if book_id in liked_books and rating >= 4:
                overlap_users.add(user_id)

# %%
# Find books which the overlapped users have read
# reclines contains potential books we want to read
rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
#rank recommendations(books) in the rec_line
import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %%
recs
# Out:
#         user_id   book_id rating
# 0            64      3590      5
# 1            64    194373      5
# 2            64      8921      4
# 3            64    194366      4
# 4            64    482060      4
# ...         ...       ...    ...
# 1560069  876054     78987      5
# 1560070  876054   8034188      0
# 1560071  876054  11870085      5
# 1560072  876054     89230      0
# 1560073  876054     88442      0
#
# [1560074 rows x 3 columns]

# %%
# Find the books with most ratings
top_recs = recs["book_id"].value_counts().head(10)

# %%
top_recs = top_recs.index.values

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#          book_id                                              title  ratings  \
# 260319  11084145                                         Steve Jobs   594067
# 284473   2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 463463      4671                                   The Great Gatsby  2758812
# 615314      5470                                               1984  2023937
# 651619  22543496                    Elon Musk: Inventing the Future    63849
# 770177      7613                                        Animal Farm  1928931
# 790927      2657                              To Kill a Mockingbird  3255518
# 876816       865                                      The Alchemist  1342863
# 878545         3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 995137     15881  Harry Potter and the Chamber of Secrets (Harry...  1821802
#
#                                                       url  \
# 260319  https://www.goodreads.com/book/show/11084145-s...
# 284473  https://www.goodreads.com/book/show/2767052-th...
# 463463  https://www.goodreads.com/book/show/4671.The_G...
# 615314      https://www.goodreads.com/book/show/5470.1984
# 651619  https://www.goodreads.com/book/show/22543496-e...
# 770177  https://www.goodreads.com/book/show/7613.Anima...
# 790927  https://www.goodreads.com/book/show/2657.To_Ki...
# 876816  https://www.goodreads.com/book/show/865.The_Al...
# 878545  https://www.goodreads.com/book/show/3.Harry_Po...
# 995137  https://www.goodreads.com/book/show/15881.Harr...
#
#                                               cover_image  \
# 260319  https://images.gr-assets.com/books/1327861368m...
# 284473  https://images.gr-assets.com/books/1447303603m...
# 463463  https://images.gr-assets.com/books/1490528560m...
# 615314  https://images.gr-assets.com/books/1348990566m...
# 651619  https://images.gr-assets.com/books/1404411386m...
# 770177  https://images.gr-assets.com/books/1424037542m...
# 790927  https://images.gr-assets.com/books/1361975680m...
# 876816  https://images.gr-assets.com/books/1483412266m...
# 878545  https://images.gr-assets.com/books/1474154022m...
# 995137  https://images.gr-assets.com/books/1474169725m...
#
#                                                 mod_title
# 260319                                         steve jobs
# 284473                the hunger games the hunger games 1
# 463463                                   the great gatsby
# 615314                                               1984
# 651619                     elon musk inventing the future
# 770177                                        animal farm
# 790927                              to kill a mockingbird
# 876816                                      the alchemist
# 878545  harry potter and the sorcerers stone harry pot...
# 995137  harry potter and the chamber of secrets harry ...

# %%
# find books that are more popular among users like us
all_recs = recs["book_id"].value_counts()

# %%
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs.head(5)
# Out:
#     book_id  book_count
# 0  22543496        2605
# 1      5470        1507
# 2         3        1507
# 3      2657        1382
# 4  11084145        1314

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
# Assign a score to compare each book( If a book is more popular among our set and less popular on goodreads it is going to be recommended)
# looking for books that are popular among users like us but not necessarily on all of goodreads
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#        book_id  book_count                                              title  \
# 706   34020885         168                          The Seduction Expert (#1)
# 0     22543496        2605                    Elon Musk: Inventing the Future
# 195     482060         379                                    Sherlock Holmes
# 667    9317691         175  The Name of the Wind (The Kingkiller Chronicle...
# 467   21032488         223      Doors of Stone (The Kingkiller Chronicle, #3)
# 8279  26860699          23        The Olympian Affair (The Cinder Spires, #2)
# 254    8153988         322           The Eye of the World (Wheel of Time, #1)
# 5258  18243345          34                        Nightblood (Warbreaker, #2)
# 490   23316526         215  The Second Machine Age: Work, Progress, and Pr...
# 548   25111341         197                       The Industries of the Future
#
#       ratings                                                url  \
# 706       115  https://www.goodreads.com/book/show/34020885-t...
# 0       63849  https://www.goodreads.com/book/show/22543496-e...
# 195      3501  https://www.goodreads.com/book/show/482060.She...
# 667      1043  https://www.goodreads.com/book/show/9317691-th...
# 467      2059  https://www.goodreads.com/book/show/21032488-d...
# 8279       27  https://www.goodreads.com/book/show/26860699-t...
# 254      5740  https://www.goodreads.com/book/show/8153988-th...
# 5258       66  https://www.goodreads.com/book/show/18243345-n...
# 490      2951  https://www.goodreads.com/book/show/23316526-t...
# 548      2765  https://www.goodreads.com/book/show/25111341-t...
#
#                                             cover_image  \
# 706   https://images.gr-assets.com/books/1500463565m...
# 0     https://images.gr-assets.com/books/1404411386m...
# 195   https://s.gr-assets.com/assets/nophoto/book/11...
# 667   https://images.gr-assets.com/books/1360558233m...
# 467   https://s.gr-assets.com/assets/nophoto/book/11...
# 8279  https://s.gr-assets.com/assets/nophoto/book/11...
# 254   https://images.gr-assets.com/books/1465920672m...
# 5258  https://s.gr-assets.com/assets/nophoto/book/11...
# 490   https://images.gr-assets.com/books/1444712959m...
# 548   https://images.gr-assets.com/books/1487178301m...
#
#                                               mod_title       score
# 706                              the seduction expert 1  245.426087
# 0                        elon musk inventing the future  106.282401
# 195                                     sherlock holmes   41.028563
# 667     the name of the wind the kingkiller chronicle 1   29.362416
# 467           doors of stone the kingkiller chronicle 3   24.152016
# 8279            the olympian affair the cinder spires 2   19.592593
# 254                the eye of the world wheel of time 1   18.063415
# 5258                            nightblood warbreaker 2   17.515152
# 490   the second machine age work progress and prosp...   15.664182
# 548                        the industries of the future   14.035805

# %%
all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False).head(10)
# Out:
#       book_id  book_count                                              title  \
# 0    22543496        2605                    Elon Musk: Inventing the Future
# 195    482060         379                                    Sherlock Holmes
# 467  21032488         223      Doors of Stone (The Kingkiller Chronicle, #3)
# 254   8153988         322           The Eye of the World (Wheel of Time, #1)
# 490  23316526         215  The Second Machine Age: Work, Progress, and Pr...
# 224  27276428         350                      The Gene: An Intimate History
# 94   17660462         527  The Everything Store: Jeff Bezos and the Age o...
# 491  22318382         215  Becoming Steve Jobs: The Evolution of a Reckle...
# 460  25666050         224  Algorithms to Live By: The Computer Science of...
# 499  12111823         212   The Winds of Winter (A Song of Ice and Fire, #6)
#
#      ratings                                                url  \
# 0      63849  https://www.goodreads.com/book/show/22543496-e...
# 195     3501  https://www.goodreads.com/book/show/482060.She...
# 467     2059  https://www.goodreads.com/book/show/21032488-d...
# 254     5740  https://www.goodreads.com/book/show/8153988-th...
# 490     2951  https://www.goodreads.com/book/show/23316526-t...
# 224     9874  https://www.goodreads.com/book/show/27276428-t...
# 94     22546  https://www.goodreads.com/book/show/17660462-t...
# 491     4224  https://www.goodreads.com/book/show/22318382-b...
# 460     4639  https://www.goodreads.com/book/show/25666050-a...
# 499     4404  https://www.goodreads.com/book/show/12111823-t...
#
#                                            cover_image  \
# 0    https://images.gr-assets.com/books/1404411386m...
# 195  https://s.gr-assets.com/assets/nophoto/book/11...
# 467  https://s.gr-assets.com/assets/nophoto/book/11...
# 254  https://images.gr-assets.com/books/1465920672m...
# 490  https://images.gr-assets.com/books/1444712959m...
# 224  https://images.gr-assets.com/books/1463591739m...
# 94   https://images.gr-assets.com/books/1365394361m...
# 491  https://images.gr-assets.com/books/1422811281m...
# 460  https://images.gr-assets.com/books/1454296875m...
# 499  https://images.gr-assets.com/books/1465341854m...
#
#                                              mod_title       score
# 0                       elon musk inventing the future  106.282401
# 195                                    sherlock holmes   41.028563
# 467          doors of stone the kingkiller chronicle 3   24.152016
# 254               the eye of the world wheel of time 1   18.063415
# 490  the second machine age work progress and prosp...   15.664182
# 224                       the gene an intimate history   12.406320
# 94   the everything store jeff bezos and the age of...   12.318327
# 491  becoming steve jobs the evolution of a reckles...   10.943419
# 460  algorithms to live by the computer science of ...   10.816124
# 499       the winds of winter a song of ice and fire 6   10.205268

# %%
popular_recs = all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)


popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_12dbe_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >book_count</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >ratings</th>
#       <th class="col_heading level0 col4" >url</th>
#       <th class="col_heading level0 col5" >cover_image</th>
#       <th class="col_heading level0 col6" >mod_title</th>
#       <th class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12dbe_level0_row0" class="row_heading level0 row0" >467</th>
#       <td id="T_12dbe_row0_col0" class="data row0 col0" >21032488</td>
#       <td id="T_12dbe_row0_col1" class="data row0 col1" >223</td>
#       <td id="T_12dbe_row0_col2" class="data row0 col2" >Doors of Stone (The Kingkiller Chronicle, #3)</td>
#       <td id="T_12dbe_row0_col3" class="data row0 col3" >2059</td>
#       <td id="T_12dbe_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/21032488-doors-of-stone">Goodreads</a></td>
#       <td id="T_12dbe_row0_col5" class="data row0 col5" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_12dbe_row0_col6" class="data row0 col6" >doors of stone the kingkiller chronicle 3</td>
#       <td id="T_12dbe_row0_col7" class="data row0 col7" >24.152016</td>
#     </tr>
#     <tr>
#       <th id="T_12dbe_level0_row1" class="row_heading level0 row1" >490</th>
#       <td id="T_12dbe_row1_col0" class="data row1 col0" >23316526</td>
#       <td id="T_12dbe_row1_col1" class="data row1 col1" >215</td>
#       <td id="T_12dbe_row1_col2" class="data row1 col2" >The Second Machine Age: Work, Progress, and Prosperity in a Time of Brilliant Technologies</td>
#       <td id="T_12dbe_row1_col3" class="data row1 col3" >2951</td>
#       <td id="T_12dbe_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/23316526-the-second-machine-age">Goodreads</a></td>
#       <td id="T_12dbe_row1_col5" class="data row1 col5" ><a href="https://images.gr-assets.com/books/1444712959m/23316526.jpg"><img src="https://images.gr-assets.com/books/1444712959m/23316526.jpg" width=50></img></a></td>
#       <td id="T_12dbe_row1_col6" class="data row1 col6" >the second machine age work progress and prosperity in a time of brilliant technologies</td>
#       <td id="T_12dbe_row1_col7" class="data row1 col7" >15.664182</td>
#     </tr>
#     <tr>
#       <th id="T_12dbe_level0_row2" class="row_heading level0 row2" >224</th>
#       <td id="T_12dbe_row2_col0" class="data row2 col0" >27276428</td>
#       <td id="T_12dbe_row2_col1" class="data row2 col1" >350</td>
#       <td id="T_12dbe_row2_col2" class="data row2 col2" >The Gene: An Intimate History</td>
#       <td id="T_12dbe_row2_col3" class="data row2 col3" >9874</td>
#       <td id="T_12dbe_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/27276428-the-gene">Goodreads</a></td>
#       <td id="T_12dbe_row2_col5" class="data row2 col5" ><a href="https://images.gr-assets.com/books/1463591739m/27276428.jpg"><img src="https://images.gr-assets.com/books/1463591739m/27276428.jpg" width=50></img></a></td>
#       <td id="T_12dbe_row2_col6" class="data row2 col6" >the gene an intimate history</td>
#       <td id="T_12dbe_row2_col7" class="data row2 col7" >12.406320</td>
#     </tr>
#     <tr>
#       <th id="T_12dbe_level0_row3" class="row_heading level0 row3" >94</th>
#       <td id="T_12dbe_row3_col0" class="data row3 col0" >17660462</td>
#       <td id="T_12dbe_row3_col1" class="data row3 col1" >527</td>
#       <td id="T_12dbe_row3_col2" class="data row3 col2" >The Everything Store: Jeff Bezos and the Age of Amazon</td>
#       <td id="T_12dbe_row3_col3" class="data row3 col3" >22546</td>
#       <td id="T_12dbe_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/17660462-the-everything-store">Goodreads</a></td>
#       <td id="T_12dbe_row3_col5" class="data row3 col5" ><a href="https://images.gr-assets.com/books/1365394361m/17660462.jpg"><img src="https://images.gr-assets.com/books/1365394361m/17660462.jpg" width=50></img></a></td>
#       <td id="T_12dbe_row3_col6" class="data row3 col6" >the everything store jeff bezos and the age of amazon</td>
#       <td id="T_12dbe_row3_col7" class="data row3 col7" >12.318327</td>
#     </tr>
#     <tr>
#       <th id="T_12dbe_level0_row4" class="row_heading level0 row4" >491</th>
#       <td id="T_12dbe_row4_col0" class="data row4 col0" >22318382</td>
#       <td id="T_12dbe_row4_col1" class="data row4 col1" >215</td>
#       <td id="T_12dbe_row4_col2" class="data row4 col2" >Becoming Steve Jobs: The Evolution of a Reckless Upstart into a Visionary Leader</td>
#       <td id="T_12dbe_row4_col3" class="data row4 col3" >4224</td>
#       <td id="T_12dbe_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/22318382-becoming-steve-jobs">Goodreads</a></td>
#       <td id="T_12dbe_row4_col5" class="data row4 col5" ><a href="https://images.gr-assets.com/books/1422811281m/22318382.jpg"><img src="https://images.gr-assets.com/books/1422811281m/22318382.jpg" width=50></img></a></td>
#       <td id="T_12dbe_row4_col6" class="data row4 col6" >becoming steve jobs the evolution of a reckless upstart into a visionary leader</td>
#       <td id="T_12dbe_row4_col7" class="data row4 col7" >10.943419</td>
#     </tr>
#     <tr>
#       <th id="T_12dbe_level0_row5" class="row_heading level0 row5" >460</th>
#       <td id="T_12dbe_row5_col0" class="data row5 col0" >25666050</td>
#       <td id="T_12dbe_row5_col1" class="data row5 col1" >224</td>
#       <td id="T_12dbe_row5_col2" class="data row5 col2" >Algorithms to Live By: The Computer Science of Human Decisions</td>
#       <td id="T_12dbe_row5_col3" class="data row5 col3" >4639</td>
#       <td id="T_12dbe_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/25666050-algorithms-to-live-by">Goodreads</a></td>
#       <td id="T_12dbe_row5_col5" class="data row5 col5" ><a href="https://images.gr-assets.com/books/1454296875m/25666050.jpg"><img src="https://images.gr-assets.com/books/1454296875m/25666050.jpg" width=50></img></a></td>
#       <td id="T_12dbe_row5_col6" class="data row5 col6" >algorithms to live by the computer science of human decisions</td>
#       <td id="T_12dbe_row5_col7" class="data row5 col7" >10.816124</td>
#     </tr>
#     <tr>
#       <th id="T_12dbe_level0_row6" class="row_heading level0 row6" >499</th>
#       <td id="T_12dbe_row6_col0" class="data row6 col0" >12111823</td>
#       <td id="T_12dbe_row6_col1" class="data row6 col1" >212</td>
#       <td id="T_12dbe_row6_col2" class="data row6 col2" >The Winds of Winter (A Song of Ice and Fire, #6)</td>
#       <td id="T_12dbe_row6_col3" class="data row6 col3" >4404</td>
#       <td id="T_12dbe_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/12111823-the-winds-of-winter">Goodreads</a></td>
#       <td id="T_12dbe_row6_col5" class="data row6 col5" ><a href="https://images.gr-assets.com/books/1465341854m/12111823.jpg"><img src="https://images.gr-assets.com/books/1465341854m/12111823.jpg" width=50></img></a></td>
#       <td id="T_12dbe_row6_col6" class="data row6 col6" >the winds of winter a song of ice and fire 6</td>
#       <td id="T_12dbe_row6_col7" class="data row6 col7" >10.205268</td>
#     </tr>
#     <tr>
#       <th id="T_12dbe_level0_row7" class="row_heading level0 row7" >477</th>
#       <td id="T_12dbe_row7_col0" class="data row7 col0" >20527133</td>
#       <td id="T_12dbe_row7_col1" class="data row7 col1" >220</td>
#       <td id="T_12dbe_row7_col2" class="data row7 col2" >Superintelligence: Paths, Dangers, Stra
